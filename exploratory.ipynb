# %%
import pandas as pd
import numpy as np
#set pandas to display all columns and rows
pd.options.display.max_columns = 2000
pd.options.display.max_rows = 2000
pd.options.display.max_colwidth = 2000
pd.options.display.width = 2000
pd.options.display.max_seq_items = 2000

np.set_printoptions(threshold=np.inf)

#load raw pollster data
pollster = pd.read_csv(r'raw-polls.csv')

pollster['race'].unique()
# Out:
# array(['1998_Gov-G_NY', '1998_Gov-G_OH', '1998_Sen-G_NV', '1998_Sen-G_NY',
#        '1998_Sen-G_OH', '1998_House-G_ID-1', '1998_House-G_ID-2',
#        '1998_House-G_US', '1998_Gov-G_AZ', '1998_Gov-G_IL',
#        '1998_Gov-G_IA', '1998_Gov-G_NE', '1998_Gov-G_WI', '1998_Sen-G_AZ',
#        '1998_Sen-G_IL', '1998_Sen-G_WI', '1998_House-G_MT-1',
#        '1998_Sen-G_GA', '1998_House-G_NC-8', '1998_Gov-G_CO',
#        '1998_Gov-G_CT', '1998_Gov-G_MD', '1998_Sen-G_CT', '1998_Sen-G_MD',
#        '1998_Gov-G_CA', '1998_Gov-G_FL', '1998_Gov-G_MN', '1998_Gov-G_NH',
#        '1998_Sen-G_FL', '1998_House-G_CA-46', '1998_House-G_IN-10',
#        '1998_Gov-G_HI', '1998_Gov-G_NM', '1998_Gov-G_RI', '1998_Sen-G_KY',
#        '1998_Sen-G_OK', '1998_House-G_HI-1', '1998_House-G_KY-6',
#        '1998_House-G_ND-1', '1998_House-G_WA-1', '1998_Gov-G_MA',
#        '1998_Sen-G_CA', '1998_Gov-G_GA', '1998_Gov-G_MI', '1998_Gov-G_PA',
# ...

# %%
#load raw presidential results data
pres_results = pd.read_csv(r'1976-2020-president.csv')

pres_results_since_2000 = pres_results[pres_results['year'] >= 2000]
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office        candidate party_detailed writein  candidatevotes  totalvotes   version  notes party_simplified
# 2042  2000  ALABAMA       AL           1         63        41  US PRESIDENT  BUSH, GEORGE W.     REPUBLICAN   False          941173     1666272  20210113    NaN       REPUBLICAN
# 2043  2000  ALABAMA       AL           1         63        41  US PRESIDENT         GORE, AL       DEMOCRAT   False          692611     1666272  20210113    NaN         DEMOCRAT
# 2044  2000  ALABAMA       AL           1         63        41  US PRESIDENT              NaN    INDEPENDENT   False           25896     1666272  20210113    NaN            OTHER
# 2045  2000  ALABAMA       AL           1         63        41  US PRESIDENT    BROWNE, HARRY    LIBERTARIAN   False            5893     1666272  20210113    NaN      LIBERTARIAN
# ...

# %%
#load senate results data
senate_results = pd.read_csv(r'1976-2020-senate.csv')
print(senate_results.head())
# Out:
#    year    state state_po  state_fips  state_cen  state_ic     office  \
# 0  1976  ARIZONA       AZ           4         86        61  US SENATE
# 1  1976  ARIZONA       AZ           4         86        61  US SENATE
# 2  1976  ARIZONA       AZ           4         86        61  US SENATE
# 3  1976  ARIZONA       AZ           4         86        61  US SENATE
# 4  1976  ARIZONA       AZ           4         86        61  US SENATE
#
#     district stage  special            candidate party_detailed  writein  \
# 0  statewide   gen    False          SAM STEIGER     REPUBLICAN    False
# 1  statewide   gen    False  WM. MATHEWS FEIGHAN    INDEPENDENT    False
# 2  statewide   gen    False     DENNIS DECONCINI       DEMOCRAT    False
# 3  statewide   gen    False        ALLAN NORWITZ    LIBERTARIAN    False
# 4  statewide   gen    False            BOB FIELD    INDEPENDENT    False
#
#     mode  candidatevotes  totalvotes  unofficial   version party_simplified
# ...

# %%
#load house results data
house_results = pd.read_csv(r'1976-2022-house.csv')
print(house_results.head())
# Out:
#    year    state state_po  state_fips  state_cen  state_ic    office  \
# 0  1976  ALABAMA       AL           1         63        41  US HOUSE
# 1  1976  ALABAMA       AL           1         63        41  US HOUSE
# 2  1976  ALABAMA       AL           1         63        41  US HOUSE
# 3  1976  ALABAMA       AL           1         63        41  US HOUSE
# 4  1976  ALABAMA       AL           1         63        41  US HOUSE
#
#    district stage runoff  special                   candidate       party  \
# 0         1   GEN  False    False              BILL DAVENPORT    DEMOCRAT
# 1         1   GEN  False    False                JACK EDWARDS  REPUBLICAN
# 2         1   GEN  False    False                     WRITEIN         NaN
# 3         2   GEN  False    False             J CAROLE KEAHEY    DEMOCRAT
# 4         2   GEN  False    False  WILLIAM L "BILL" DICKINSON  REPUBLICAN
#
#    writein   mode  candidatevotes  totalvotes  unofficial   version  \
# ...
